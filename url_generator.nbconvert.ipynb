# %%
# !pip install fastcore --upgrade
# !pip install git+https://github.com/Living-with-machines/hmd_newspaper_dl
# Out:
# Requirement already satisfied: fastcore in /opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages (1.3.6)
# Collecting fastcore
#   Downloading fastcore-1.5.27-py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 kB 18.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages (from fastcore) (21.3)
# Requirement already satisfied: pip in /opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages (from fastcore) (22.2.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages (from packaging->fastcore) (3.0.9)
# Installing collected packages: fastcore
#   Attempting uninstall: fastcore
#     Found existing installation: fastcore 1.3.6
#     Uninstalling fastcore-1.3.6:
#       Successfully uninstalled fastcore-1.3.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gh-orgstats 0.0.1 requires fastcore==1.3.6, but you have fastcore 1.5.27 which is incompatible.
# Successfully installed fastcore-1.5.27
# Collecting git+https://github.com/Living-with-machines/hmd_newspaper_dl
#   Cloning https://github.com/Living-with-machines/hmd_newspaper_dl to /tmp/pip-req-build-kulxfwcg
#   Running command git clone --filter=blob:none --quiet https://github.com/Living-with-machines/hmd_newspaper_dl /tmp/pip-req-build-kulxfwcg
#   Resolved https://github.com/Living-with-machines/hmd_newspaper_dl to commit 701ea81e0ef18907f947c55003aba29fca6533e5
# done
# Requirement already satisfied: requests in /opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages (from hmd-newspaper-dl==0.0.2) (2.28.1)
# Requirement already satisfied: beautifulsoup4 in /opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages (from hmd-newspaper-dl==0.0.2) (4.11.1)
# Collecting tqdm
#   Downloading tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 16.0 MB/s eta 0:00:00
# Collecting loguru
#   Downloading loguru-0.6.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 17.2 MB/s eta 0:00:00
# Requirement already satisfied: lxml in /opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages (from hmd-newspaper-dl==0.0.2) (4.9.1)
# Requirement already satisfied: fastcore in /opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages (from hmd-newspaper-dl==0.0.2) (1.5.27)
# Collecting nbdev
#   Downloading nbdev-2.3.7-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.5/63.5 kB 15.7 MB/s eta 0:00:00
# Requirement already satisfied: soupsieve>1.2 in /opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages (from beautifulsoup4->hmd-newspaper-dl==0.0.2) (2.3.2.post1)
# Requirement already satisfied: packaging in /opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages (from fastcore->hmd-newspaper-dl==0.0.2) (21.3)
# Requirement already satisfied: pip in /opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages (from fastcore->hmd-newspaper-dl==0.0.2) (22.2.2)
# Collecting PyYAML
#   Downloading PyYAML-6.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (701 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 701.2/701.2 kB 51.8 MB/s eta 0:00:00
# Collecting watchdog
#   Downloading watchdog-2.1.9-py3-none-manylinux2014_x86_64.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 14.8 MB/s eta 0:00:00
# Collecting astunparse
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting ghapi>=1.0.3
#   Downloading ghapi-1.0.3-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 kB 14.3 MB/s eta 0:00:00
# Collecting execnb>=0.1.4
#   Downloading execnb-0.1.4-py3-none-any.whl (13 kB)
# Requirement already satisfied: asttokens in /opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages (from nbdev->hmd-newspaper-dl==0.0.2) (2.0.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages (from requests->hmd-newspaper-dl==0.0.2) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages (from requests->hmd-newspaper-dl==0.0.2) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages (from requests->hmd-newspaper-dl==0.0.2) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages (from requests->hmd-newspaper-dl==0.0.2) (3.4)
# Requirement already satisfied: ipython in /opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages (from execnb>=0.1.4->nbdev->hmd-newspaper-dl==0.0.2) (8.5.0)
# Requirement already satisfied: six in /opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages (from asttokens->nbdev->hmd-newspaper-dl==0.0.2) (1.16.0)
# Collecting wheel<1.0,>=0.23.0
#   Downloading wheel-0.37.1-py2.py3-none-any.whl (35 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages (from packaging->fastcore->hmd-newspaper-dl==0.0.2) (3.0.9)
# Requirement already satisfied: jedi>=0.16 in /opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages (from ipython->execnb>=0.1.4->nbdev->hmd-newspaper-dl==0.0.2) (0.18.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in /opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages (from ipython->execnb>=0.1.4->nbdev->hmd-newspaper-dl==0.0.2) (3.0.31)
# Requirement already satisfied: backcall in /opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages (from ipython->execnb>=0.1.4->nbdev->hmd-newspaper-dl==0.0.2) (0.2.0)
# Requirement already satisfied: pygments>=2.4.0 in /opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages (from ipython->execnb>=0.1.4->nbdev->hmd-newspaper-dl==0.0.2) (2.13.0)
# Requirement already satisfied: decorator in /opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages (from ipython->execnb>=0.1.4->nbdev->hmd-newspaper-dl==0.0.2) (5.1.1)
# Requirement already satisfied: matplotlib-inline in /opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages (from ipython->execnb>=0.1.4->nbdev->hmd-newspaper-dl==0.0.2) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages (from ipython->execnb>=0.1.4->nbdev->hmd-newspaper-dl==0.0.2) (4.8.0)
# Requirement already satisfied: stack-data in /opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages (from ipython->execnb>=0.1.4->nbdev->hmd-newspaper-dl==0.0.2) (0.5.1)
# Requirement already satisfied: pickleshare in /opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages (from ipython->execnb>=0.1.4->nbdev->hmd-newspaper-dl==0.0.2) (0.7.5)
# Requirement already satisfied: traitlets>=5 in /opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages (from ipython->execnb>=0.1.4->nbdev->hmd-newspaper-dl==0.0.2) (5.4.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages (from jedi>=0.16->ipython->execnb>=0.1.4->nbdev->hmd-newspaper-dl==0.0.2) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages (from pexpect>4.3->ipython->execnb>=0.1.4->nbdev->hmd-newspaper-dl==0.0.2) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython->execnb>=0.1.4->nbdev->hmd-newspaper-dl==0.0.2) (0.2.5)
# Requirement already satisfied: pure-eval in /opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages (from stack-data->ipython->execnb>=0.1.4->nbdev->hmd-newspaper-dl==0.0.2) (0.2.2)
# Requirement already satisfied: executing in /opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages (from stack-data->ipython->execnb>=0.1.4->nbdev->hmd-newspaper-dl==0.0.2) (1.1.0)
# Using legacy 'setup.py install' for hmd-newspaper-dl, since package 'wheel' is not installed.
# Installing collected packages: wheel, watchdog, tqdm, PyYAML, loguru, astunparse, ghapi, execnb, nbdev, hmd-newspaper-dl
# done
# Successfully installed PyYAML-6.0 astunparse-1.6.3 execnb-0.1.4 ghapi-1.0.3 hmd-newspaper-dl-0.0.2 loguru-0.6.0 nbdev-2.3.7 tqdm-4.64.1 watchdog-2.1.9 wheel-0.37.1

# %%
from hmd_newspaper_dl.core import get_download_urls, get_newspaper_links
from tqdm.auto import tqdm
import re
import json
from hmd_newspaper_dl.core import _download

# %%
title_urls = get_newspaper_links()

# %%
title_urls[0]
# Out:
# ('The Express',
#  'https://bl.iro.bl.uk/concern/datasets/93ec8ab4-3348-409c-bf6d-a9537156f654?locale=en')

# %%
#sample = title_urls[:2]

# %%
def infer_date_from_fname(fname:str):
    parts = re.split(r"_|\.",fname)
    for p in parts:
        if len(p)==4:
            return p
    else:
        print(fname)

# %%
title_download_urls = {}
for title, url in tqdm(title_urls):
    download_urls = get_download_urls(url)
    date_dict = {}
    for url in tqdm(download_urls, leave=False):
        fname = _download(url, return_filename_only=True,sleepy=False)
        date = infer_date_from_fname(fname)
        #{date: {"url": url, "fname":fname}}
        # date_dict['url']= url
        # date_dict['fname'] = fname
        date_dict[date] = {"url": url, "fname":fname}
    title_download_urls[title] = date_dict
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/23 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/31 [00:00<?, ?it/s]
#   0%|          | 0/15 [00:00<?, ?it/s]
#   0%|          | 0/15 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/70 [00:00<?, ?it/s]
#   0%|          | 0/24 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
# readme.txt
#   0%|          | 0/9 [00:00<?, ?it/s]
# readme.txt

# %%
with open('HMD_title_urls.json', 'w') as f:
    json.dump(title_download_urls, f)
