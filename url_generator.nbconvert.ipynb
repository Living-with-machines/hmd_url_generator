# %%
# !pip install fastcore --upgrade
# !pip install git+https://github.com/Living-with-machines/hmd_newspaper_dl
# Out:
# Requirement already satisfied: fastcore in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (1.3.6)
# Collecting fastcore
#   Downloading fastcore-1.4.5-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 kB 12.6 MB/s eta 0:00:00
# Requirement already satisfied: pip in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from fastcore) (22.1.2)
# Requirement already satisfied: packaging in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from fastcore) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from packaging->fastcore) (3.0.9)
# Installing collected packages: fastcore
#   Attempting uninstall: fastcore
#     Found existing installation: fastcore 1.3.6
#     Uninstalling fastcore-1.3.6:
#       Successfully uninstalled fastcore-1.3.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gh-orgstats 0.0.1 requires fastcore==1.3.6, but you have fastcore 1.4.5 which is incompatible.
# Successfully installed fastcore-1.4.5
# Collecting git+https://github.com/Living-with-machines/hmd_newspaper_dl
#   Cloning https://github.com/Living-with-machines/hmd_newspaper_dl to /tmp/pip-req-build-ds49cob0
#   Running command git clone --filter=blob:none --quiet https://github.com/Living-with-machines/hmd_newspaper_dl /tmp/pip-req-build-ds49cob0
#   Resolved https://github.com/Living-with-machines/hmd_newspaper_dl to commit 701ea81e0ef18907f947c55003aba29fca6533e5
# done
# Requirement already satisfied: requests in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from hmd-newspaper-dl==0.0.2) (2.28.0)
# Requirement already satisfied: beautifulsoup4 in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from hmd-newspaper-dl==0.0.2) (4.11.1)
# Collecting tqdm
#   Downloading tqdm-4.64.0-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 9.9 MB/s eta 0:00:00
# Collecting loguru
#   Downloading loguru-0.6.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 27.6 MB/s eta 0:00:00
# Collecting lxml
#   Downloading lxml-4.9.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 109.6 MB/s eta 0:00:00
# Requirement already satisfied: fastcore in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from hmd-newspaper-dl==0.0.2) (1.4.5)
# Collecting nbdev
#   Downloading nbdev-1.2.10-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 23.1 MB/s eta 0:00:00
# Requirement already satisfied: soupsieve>1.2 in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from beautifulsoup4->hmd-newspaper-dl==0.0.2) (2.3.2.post1)
# Requirement already satisfied: packaging in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from fastcore->hmd-newspaper-dl==0.0.2) (21.3)
# Requirement already satisfied: pip in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from fastcore->hmd-newspaper-dl==0.0.2) (22.1.2)
# Collecting fastrelease
#   Downloading fastrelease-0.1.16-py3-none-any.whl (13 kB)
# Requirement already satisfied: nbconvert>=6.1 in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from nbdev->hmd-newspaper-dl==0.0.2) (6.5.0)
# Requirement already satisfied: Jinja2 in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from nbdev->hmd-newspaper-dl==0.0.2) (3.1.2)
# Requirement already satisfied: jupyter-client<8 in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from nbdev->hmd-newspaper-dl==0.0.2) (7.3.4)
# Requirement already satisfied: ipykernel in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from nbdev->hmd-newspaper-dl==0.0.2) (6.15.0)
# Collecting pyyaml
#   Downloading PyYAML-6.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (701 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 701.2/701.2 kB 104.9 MB/s eta 0:00:00
# Collecting ghapi
#   Downloading ghapi-0.1.21-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 25.2 MB/s eta 0:00:00
# Requirement already satisfied: nbformat>=4.4.0 in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from nbdev->hmd-newspaper-dl==0.0.2) (5.4.0)
# Requirement already satisfied: jupyter in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from nbdev->hmd-newspaper-dl==0.0.2) (1.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from requests->hmd-newspaper-dl==0.0.2) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from requests->hmd-newspaper-dl==0.0.2) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from requests->hmd-newspaper-dl==0.0.2) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from requests->hmd-newspaper-dl==0.0.2) (3.3)
# Requirement already satisfied: nest-asyncio>=1.5.4 in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from jupyter-client<8->nbdev->hmd-newspaper-dl==0.0.2) (1.5.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from jupyter-client<8->nbdev->hmd-newspaper-dl==0.0.2) (2.8.2)
# Requirement already satisfied: traitlets in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from jupyter-client<8->nbdev->hmd-newspaper-dl==0.0.2) (5.3.0)
# Requirement already satisfied: pyzmq>=23.0 in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from jupyter-client<8->nbdev->hmd-newspaper-dl==0.0.2) (23.2.0)
# Requirement already satisfied: entrypoints in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from jupyter-client<8->nbdev->hmd-newspaper-dl==0.0.2) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from jupyter-client<8->nbdev->hmd-newspaper-dl==0.0.2) (4.10.0)
# Requirement already satisfied: tornado>=6.0 in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from jupyter-client<8->nbdev->hmd-newspaper-dl==0.0.2) (6.1)
# Requirement already satisfied: defusedxml in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from nbconvert>=6.1->nbdev->hmd-newspaper-dl==0.0.2) (0.7.1)
# Requirement already satisfied: pygments>=2.4.1 in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from nbconvert>=6.1->nbdev->hmd-newspaper-dl==0.0.2) (2.12.0)
# Requirement already satisfied: jupyterlab-pygments in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from nbconvert>=6.1->nbdev->hmd-newspaper-dl==0.0.2) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from nbconvert>=6.1->nbdev->hmd-newspaper-dl==0.0.2) (0.8.4)
# Requirement already satisfied: tinycss2 in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from nbconvert>=6.1->nbdev->hmd-newspaper-dl==0.0.2) (1.1.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from nbconvert>=6.1->nbdev->hmd-newspaper-dl==0.0.2) (1.5.0)
# Requirement already satisfied: bleach in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from nbconvert>=6.1->nbdev->hmd-newspaper-dl==0.0.2) (5.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from nbconvert>=6.1->nbdev->hmd-newspaper-dl==0.0.2) (2.1.1)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from nbconvert>=6.1->nbdev->hmd-newspaper-dl==0.0.2) (0.6.4)
# Requirement already satisfied: jsonschema>=2.6 in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from nbformat>=4.4.0->nbdev->hmd-newspaper-dl==0.0.2) (4.6.0)
# Requirement already satisfied: fastjsonschema in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from nbformat>=4.4.0->nbdev->hmd-newspaper-dl==0.0.2) (2.15.3)
# Requirement already satisfied: psutil in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from ipykernel->nbdev->hmd-newspaper-dl==0.0.2) (5.9.1)
# Requirement already satisfied: ipython>=7.23.1 in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from ipykernel->nbdev->hmd-newspaper-dl==0.0.2) (8.4.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from ipykernel->nbdev->hmd-newspaper-dl==0.0.2) (0.1.3)
# Requirement already satisfied: debugpy>=1.0 in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from ipykernel->nbdev->hmd-newspaper-dl==0.0.2) (1.6.0)
# Requirement already satisfied: ipywidgets in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from jupyter->nbdev->hmd-newspaper-dl==0.0.2) (7.7.1)
# Requirement already satisfied: qtconsole in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from jupyter->nbdev->hmd-newspaper-dl==0.0.2) (5.3.1)
# Requirement already satisfied: notebook in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from jupyter->nbdev->hmd-newspaper-dl==0.0.2) (6.4.12)
# Requirement already satisfied: jupyter-console in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from jupyter->nbdev->hmd-newspaper-dl==0.0.2) (6.4.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from packaging->fastcore->hmd-newspaper-dl==0.0.2) (3.0.9)
# Requirement already satisfied: pickleshare in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->nbdev->hmd-newspaper-dl==0.0.2) (0.7.5)
# Requirement already satisfied: decorator in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->nbdev->hmd-newspaper-dl==0.0.2) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->nbdev->hmd-newspaper-dl==0.0.2) (0.18.1)
# Requirement already satisfied: backcall in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->nbdev->hmd-newspaper-dl==0.0.2) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->nbdev->hmd-newspaper-dl==0.0.2) (56.0.0)
# Requirement already satisfied: pexpect>4.3 in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->nbdev->hmd-newspaper-dl==0.0.2) (4.8.0)
# Requirement already satisfied: stack-data in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->nbdev->hmd-newspaper-dl==0.0.2) (0.3.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->nbdev->hmd-newspaper-dl==0.0.2) (3.0.29)
# Requirement already satisfied: attrs>=17.4.0 in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat>=4.4.0->nbdev->hmd-newspaper-dl==0.0.2) (21.4.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat>=4.4.0->nbdev->hmd-newspaper-dl==0.0.2) (5.8.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat>=4.4.0->nbdev->hmd-newspaper-dl==0.0.2) (0.18.1)
# Requirement already satisfied: six>=1.5 in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from python-dateutil>=2.8.2->jupyter-client<8->nbdev->hmd-newspaper-dl==0.0.2) (1.16.0)
# Requirement already satisfied: webencodings in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from bleach->nbconvert>=6.1->nbdev->hmd-newspaper-dl==0.0.2) (0.5.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from ipywidgets->jupyter->nbdev->hmd-newspaper-dl==0.0.2) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from ipywidgets->jupyter->nbdev->hmd-newspaper-dl==0.0.2) (1.1.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from ipywidgets->jupyter->nbdev->hmd-newspaper-dl==0.0.2) (3.6.1)
# Requirement already satisfied: terminado>=0.8.3 in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from notebook->jupyter->nbdev->hmd-newspaper-dl==0.0.2) (0.15.0)
# Requirement already satisfied: prometheus-client in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from notebook->jupyter->nbdev->hmd-newspaper-dl==0.0.2) (0.14.1)
# Requirement already satisfied: argon2-cffi in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from notebook->jupyter->nbdev->hmd-newspaper-dl==0.0.2) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from notebook->jupyter->nbdev->hmd-newspaper-dl==0.0.2) (1.8.0)
# Requirement already satisfied: qtpy>=2.0.1 in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from qtconsole->jupyter->nbdev->hmd-newspaper-dl==0.0.2) (2.1.0)
# Requirement already satisfied: zipp>=3.1.0 in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat>=4.4.0->nbdev->hmd-newspaper-dl==0.0.2) (3.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->nbdev->hmd-newspaper-dl==0.0.2) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->nbdev->hmd-newspaper-dl==0.0.2) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel->nbdev->hmd-newspaper-dl==0.0.2) (0.2.5)
# Requirement already satisfied: argon2-cffi-bindings in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from argon2-cffi->notebook->jupyter->nbdev->hmd-newspaper-dl==0.0.2) (21.2.0)
# Requirement already satisfied: asttokens in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel->nbdev->hmd-newspaper-dl==0.0.2) (2.0.5)
# Requirement already satisfied: pure-eval in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel->nbdev->hmd-newspaper-dl==0.0.2) (0.2.2)
# Requirement already satisfied: executing in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel->nbdev->hmd-newspaper-dl==0.0.2) (0.8.3)
# Requirement already satisfied: cffi>=1.0.1 in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->nbdev->hmd-newspaper-dl==0.0.2) (1.15.0)
# Requirement already satisfied: pycparser in /opt/hostedtoolcache/Python/3.8.12/x64/lib/python3.8/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->nbdev->hmd-newspaper-dl==0.0.2) (2.21)
# Using legacy 'setup.py install' for hmd-newspaper-dl, since package 'wheel' is not installed.
# Installing collected packages: tqdm, pyyaml, lxml, loguru, ghapi, fastrelease, nbdev, hmd-newspaper-dl
# done
# Successfully installed fastrelease-0.1.16 ghapi-0.1.21 hmd-newspaper-dl-0.0.2 loguru-0.6.0 lxml-4.9.0 nbdev-1.2.10 pyyaml-6.0 tqdm-4.64.0

# %%
from hmd_newspaper_dl.core import get_download_urls, get_newspaper_links
from tqdm.auto import tqdm
import re
import json
from hmd_newspaper_dl.core import _download

# %%
title_urls = get_newspaper_links()

# %%
title_urls[0]
# Out:
# ('The Express',
#  'https://bl.iro.bl.uk/concern/datasets/93ec8ab4-3348-409c-bf6d-a9537156f654?locale=en')

# %%
#sample = title_urls[:2]

# %%
def infer_date_from_fname(fname:str):
    parts = re.split(r"_|\.",fname)
    for p in parts:
        if len(p)==4:
            return p
    else:
        print(fname)

# %%
title_download_urls = {}
for title, url in tqdm(title_urls):
    download_urls = get_download_urls(url)
    date_dict = {}
    for url in tqdm(download_urls, leave=False):
        fname = _download(url, return_filename_only=True,sleepy=False)
        date = infer_date_from_fname(fname)
        #{date: {"url": url, "fname":fname}}
        # date_dict['url']= url
        # date_dict['fname'] = fname
        date_dict[date] = {"url": url, "fname":fname}
    title_download_urls[title] = date_dict
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/23 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/31 [00:00<?, ?it/s]
#   0%|          | 0/15 [00:00<?, ?it/s]
#   0%|          | 0/15 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/70 [00:00<?, ?it/s]
#   0%|          | 0/24 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
# readme.txt
#   0%|          | 0/9 [00:00<?, ?it/s]
# readme.txt

# %%
with open('HMD_title_urls.json', 'w') as f:
    json.dump(title_download_urls, f)
