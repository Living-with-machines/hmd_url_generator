# %%
# !pip install git+https://github.com/Living-with-machines/hmd_newspaper_dl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/Living-with-machines/hmd_newspaper_dl
#   Cloning https://github.com/Living-with-machines/hmd_newspaper_dl to /tmp/pip-req-build-iujj0etm
#   Running command git clone -q https://github.com/Living-with-machines/hmd_newspaper_dl /tmp/pip-req-build-iujj0etm
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from hmd-newspaper-dl==0.0.2) (2.23.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from hmd-newspaper-dl==0.0.2) (4.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from hmd-newspaper-dl==0.0.2) (4.64.0)
# Collecting loguru
#   Downloading loguru-0.6.0-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 2.6 MB/s
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from hmd-newspaper-dl==0.0.2) (4.2.6)
# Collecting fastcore
#   Downloading fastcore-1.4.4-py3-none-any.whl (60 kB)
#      |████████████████████████████████| 60 kB 2.8 MB/s
# Collecting nbdev
#   Downloading nbdev-1.2.9-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 6.4 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from fastcore->hmd-newspaper-dl==0.0.2) (21.3)
# Requirement already satisfied: pip in /usr/local/lib/python3.7/dist-packages (from fastcore->hmd-newspaper-dl==0.0.2) (21.1.3)
# Requirement already satisfied: jupyter-client<8 in /usr/local/lib/python3.7/dist-packages (from nbdev->hmd-newspaper-dl==0.0.2) (5.3.5)
# Collecting fastrelease
#   Downloading fastrelease-0.1.16-py3-none-any.whl (13 kB)
# Requirement already satisfied: nbformat>=4.4.0 in /usr/local/lib/python3.7/dist-packages (from nbdev->hmd-newspaper-dl==0.0.2) (5.4.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from nbdev->hmd-newspaper-dl==0.0.2) (3.13)
# Requirement already satisfied: Jinja2 in /usr/local/lib/python3.7/dist-packages (from nbdev->hmd-newspaper-dl==0.0.2) (2.11.3)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.7/dist-packages (from nbdev->hmd-newspaper-dl==0.0.2) (4.10.1)
# Requirement already satisfied: jupyter in /usr/local/lib/python3.7/dist-packages (from nbdev->hmd-newspaper-dl==0.0.2) (1.0.0)
# Collecting nbconvert>=6.1
#   Downloading nbconvert-6.5.0-py3-none-any.whl (561 kB)
#      |████████████████████████████████| 561 kB 28.1 MB/s
# Collecting ghapi
#   Downloading ghapi-0.1.21-py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 2.5 MB/s
# Requirement already satisfied: tornado>=4.1 in /usr/local/lib/python3.7/dist-packages (from jupyter-client<8->nbdev->hmd-newspaper-dl==0.0.2) (5.1.1)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from jupyter-client<8->nbdev->hmd-newspaper-dl==0.0.2) (2.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.7/dist-packages (from jupyter-client<8->nbdev->hmd-newspaper-dl==0.0.2) (4.10.0)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client<8->nbdev->hmd-newspaper-dl==0.0.2) (23.1.0)
# Requirement already satisfied: traitlets in /usr/local/lib/python3.7/dist-packages (from jupyter-client<8->nbdev->hmd-newspaper-dl==0.0.2) (5.1.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.7/dist-packages (from nbconvert>=6.1->nbdev->hmd-newspaper-dl==0.0.2) (0.2.2)
# Collecting Jinja2
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 53.6 MB/s
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from nbconvert>=6.1->nbdev->hmd-newspaper-dl==0.0.2) (0.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert>=6.1->nbdev->hmd-newspaper-dl==0.0.2) (1.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert>=6.1->nbdev->hmd-newspaper-dl==0.0.2) (0.8.4)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert>=6.1->nbdev->hmd-newspaper-dl==0.0.2) (5.0.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.7/dist-packages (from nbconvert>=6.1->nbdev->hmd-newspaper-dl==0.0.2) (1.1.1)
# Requirement already satisfied: pygments>=2.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert>=6.1->nbdev->hmd-newspaper-dl==0.0.2) (2.6.1)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from nbconvert>=6.1->nbdev->hmd-newspaper-dl==0.0.2) (0.6.4)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert>=6.1->nbdev->hmd-newspaper-dl==0.0.2) (0.7.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.7/dist-packages (from nbconvert>=6.1->nbdev->hmd-newspaper-dl==0.0.2) (2.0.1)
# Collecting traitlets
#   Downloading traitlets-5.3.0-py3-none-any.whl (106 kB)
#      |████████████████████████████████| 106 kB 57.2 MB/s
# Collecting jupyter-client<8
#   Downloading jupyter_client-7.3.4-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 60.1 MB/s
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.7/dist-packages (from nbclient>=0.5.0->nbconvert>=6.1->nbdev->hmd-newspaper-dl==0.0.2) (1.5.5)
# Collecting tornado>=4.1
#   Downloading tornado-6.1-cp37-cp37m-manylinux2010_x86_64.whl (428 kB)
#      |████████████████████████████████| 428 kB 54.7 MB/s
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.4.0->nbdev->hmd-newspaper-dl==0.0.2) (2.15.3)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.4.0->nbdev->hmd-newspaper-dl==0.0.2) (4.3.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat>=4.4.0->nbdev->hmd-newspaper-dl==0.0.2) (21.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat>=4.4.0->nbdev->hmd-newspaper-dl==0.0.2) (4.11.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat>=4.4.0->nbdev->hmd-newspaper-dl==0.0.2) (4.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat>=4.4.0->nbdev->hmd-newspaper-dl==0.0.2) (0.18.1)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat>=4.4.0->nbdev->hmd-newspaper-dl==0.0.2) (5.7.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat>=4.4.0->nbdev->hmd-newspaper-dl==0.0.2) (3.8.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.1->jupyter-client<8->nbdev->hmd-newspaper-dl==0.0.2) (1.15.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert>=6.1->nbdev->hmd-newspaper-dl==0.0.2) (0.5.1)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel->nbdev->hmd-newspaper-dl==0.0.2) (5.5.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipykernel->nbdev->hmd-newspaper-dl==0.0.2) (0.7.5)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipykernel->nbdev->hmd-newspaper-dl==0.0.2) (4.8.0)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipykernel->nbdev->hmd-newspaper-dl==0.0.2) (1.0.18)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipykernel->nbdev->hmd-newspaper-dl==0.0.2) (4.4.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipykernel->nbdev->hmd-newspaper-dl==0.0.2) (57.4.0)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipykernel->nbdev->hmd-newspaper-dl==0.0.2) (0.8.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=4.0.0->ipykernel->nbdev->hmd-newspaper-dl==0.0.2) (0.2.5)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.7/dist-packages (from jupyter->nbdev->hmd-newspaper-dl==0.0.2) (7.7.0)
# Requirement already satisfied: notebook in /usr/local/lib/python3.7/dist-packages (from jupyter->nbdev->hmd-newspaper-dl==0.0.2) (5.3.1)
# Requirement already satisfied: qtconsole in /usr/local/lib/python3.7/dist-packages (from jupyter->nbdev->hmd-newspaper-dl==0.0.2) (5.3.1)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.7/dist-packages (from jupyter->nbdev->hmd-newspaper-dl==0.0.2) (5.2.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->jupyter->nbdev->hmd-newspaper-dl==0.0.2) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->jupyter->nbdev->hmd-newspaper-dl==0.0.2) (1.1.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->jupyter->nbdev->hmd-newspaper-dl==0.0.2) (3.6.0)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook->jupyter->nbdev->hmd-newspaper-dl==0.0.2) (0.13.3)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook->jupyter->nbdev->hmd-newspaper-dl==0.0.2) (1.8.0)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.7/dist-packages (from terminado>=0.8.1->notebook->jupyter->nbdev->hmd-newspaper-dl==0.0.2) (0.7.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->fastcore->hmd-newspaper-dl==0.0.2) (3.0.9)
# Requirement already satisfied: qtpy>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from qtconsole->jupyter->nbdev->hmd-newspaper-dl==0.0.2) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->hmd-newspaper-dl==0.0.2) (2022.5.18.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->hmd-newspaper-dl==0.0.2) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->hmd-newspaper-dl==0.0.2) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->hmd-newspaper-dl==0.0.2) (3.0.4)
# Building wheels for collected packages: hmd-newspaper-dl
#   Building wheel for hmd-newspaper-dl (setup.py) ... done
#   Created wheel for hmd-newspaper-dl: filename=hmd_newspaper_dl-0.0.2-py3-none-any.whl size=7026 sha256=2a1c18fd736497e1f5a64e4cef910d33485ec9b47b1da5ca42ec4ed7a709f4a8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-la4u5zze/wheels/e0/30/91/8e5411005b0257d35cc6a18ef74d00405956c0adf00f26c941
# Successfully built hmd-newspaper-dl
# Installing collected packages: traitlets, tornado, jupyter-client, Jinja2, nbconvert, fastcore, ghapi, fastrelease, nbdev, loguru, hmd-newspaper-dl
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.1.1
#     Uninstalling traitlets-5.1.1:
#       Successfully uninstalled traitlets-5.1.1
#   Attempting uninstall: tornado
#     Found existing installation: tornado 5.1.1
#     Uninstalling tornado-5.1.1:
#       Successfully uninstalled tornado-5.1.1
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 5.3.5
#     Uninstalling jupyter-client-5.3.5:
#       Successfully uninstalled jupyter-client-5.3.5
#   Attempting uninstall: Jinja2
#     Found existing installation: Jinja2 2.11.3
#     Uninstalling Jinja2-2.11.3:
#       Successfully uninstalled Jinja2-2.11.3
#   Attempting uninstall: nbconvert
#     Found existing installation: nbconvert 5.6.1
#     Uninstalling nbconvert-5.6.1:
#       Successfully uninstalled nbconvert-5.6.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires tornado~=5.1.0; python_version >= "3.0", but you have tornado 6.1 which is incompatible.
# flask 1.1.4 requires Jinja2<3.0,>=2.10.1, but you have jinja2 3.1.2 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed Jinja2-3.1.2 fastcore-1.4.4 fastrelease-0.1.16 ghapi-0.1.21 hmd-newspaper-dl-0.0.2 jupyter-client-7.3.4 loguru-0.6.0 nbconvert-6.5.0 nbdev-1.2.9 tornado-6.1 traitlets-5.3.0

# %%
from hmd_newspaper_dl.core import get_download_urls, get_newspaper_links
from tqdm.auto import tqdm
import re
import json
from hmd_newspaper_dl.core import _download

# %%
title_urls = get_newspaper_links()

# %%
title_urls[0]
# Out:
# ('The Express',
#  'https://bl.iro.bl.uk/concern/datasets/93ec8ab4-3348-409c-bf6d-a9537156f654?locale=en')

# %%
sample = title_urls[:2]

# %%
def infer_date_from_fname(fname:str):
    parts = re.split(r"_|\.",fname)
    for p in parts:
        if len(p)==4:
            return p
    else:
        print(fname)

# %%
title_download_urls = {}
for title, url in tqdm(sample):
    download_urls = get_download_urls(url)
    date_dict = {}
    for url in tqdm(download_urls, leave=False):
        fname = _download(url, return_filename_only=True,sleepy=False)
        date = infer_date_from_fname(fname)
        #{date: {"url": url, "fname":fname}}
        # date_dict['url']= url
        # date_dict['fname'] = fname
        date_dict[date] = {"url": url, "fname":fname}
    title_download_urls[title] = date_dict
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/23 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]

# %%
with open('HMD_title_urls.json', 'w') as f:
    json.dump(title_download_urls, f)
